# %%
import pandas as pd

from modules.get_songs_by_genre import get_songs_data_by_genre

# %%
genres = [
    "pop",
    "rock",
    "hip hop",
    "jazz",
    "blues",
    "classical",
    "country",
    "electronic",
    "dance",
    "reggae",
    "soul",
    "funk",
    "disco",
    "r&b",
    "metal",
    "punk",
    "indie",
    "alternative",
    "latin",
    "k-pop",
    "j-pop",
    "reggaeton",
    "ska",
    "trap",
    "house",
    "techno",
    "trance",
    "dubstep",
    "drum and bass",
    "ambient",
    "chillout",
    "lo-fi",
    "acoustic",
    "world",
    "salsa",
    "bachata",
    "merengue",
    "cumbia",
    "flamenco",
    "gospel",
    "opera",
    "new age",
    "industrial",
    "grunge",
    "garage",
    "britpop",
    "glam rock",
    "synthpop",
    "electropop",
    "downtempo",
    "vaporwave",
    "synthwave",
    "emo",
    "hardcore",
    "post-rock",
    "post-punk",
    "blues rock",
    "psychedelic",
    "progressive rock",
    "avant-garde",
    "experimental",
    "classical crossover",
    "soundtrack",
    "video game music",
    "musical theater",
    "singer-songwriter",
    "contemporary r&b",
    "neo soul",
    "motown",
    "doo-wop",
    "swing",
    "bebop",
    "hard bop",
    "free jazz",
    "smooth jazz",
    "jazz fusion",
    "bluegrass",
    "zydeco",
    "cajun",
    "latin jazz",
    "bossa nova",
    "samba",
    "afrobeat",
    "afro-cuban",
    "highlife",
    "klezmer",
    "tango",
    "bollywood",
    "hindustani",
    "carnatic",
    "sufi",
    "celtic",
    "medieval",
    "renaissance",
    "baroque",
    "romantic classical",
    "impressionist",
    "minimalism",
    "drone",
    "black metal",
    "death metal",
    "thrash metal",
    "doom metal",
    "power metal",
    "symphonic metal",
    "gothic metal",
    "shoegaze",
    "dream pop",
    "math rock",
    "noise rock",
    "krautrock",
    "art rock",
    "desert blues",
    "nordic folk",
    "nordic metal",
    "dub",
    "rocksteady",
    "ska punk",
    "pop punk",
    "new wave",
    "synth-pop",
    "electronica",
    "big band",
    "bebop",
    "drill",
    "grime",
    "vaportrap",
    "deep house",
    "tropical house",
    "progressive house",
    "big room",
    "moombahton",
    "future bass",
    "bounce",
    "happy hardcore",
    "hardstyle",
    "gabber",
    "psytrance",
    "goa trance",
    "acid jazz",
    "jazztronica",
    "funktronica",
    "electro swing",
    "fusion",
    "contemporary classical",
    "avant-garde jazz",
    "space rock",
    "stoner rock",
    "latin pop",
]

# %%
all_data = pd.DataFrame()
for genre in genres:
    data = get_songs_data_by_genre(genre, limit=50, max_results=500)
    name = genre.replace(" ", "_")
    data.to_csv(f"{genre}.csv")
    all_data = pd.concat([all_data, data], ignore_index=True)
# Out:
# Error al realizar la búsqueda de género gospel en offset 0: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/search?q=genre:gospel&type=track&limit=50&offset=0 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa3f0808ca0>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# Error al realizar la búsqueda de género vaporwave en offset 0: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/search?q=genre:vaporwave&type=track&limit=50&offset=0 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa3f0808880>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# ...
